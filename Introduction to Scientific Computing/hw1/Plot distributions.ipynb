# %%
from assigment import perform_experiment
import matplotlib.pyplot as plt

# %%
random, optimized = perform_experiment()
# Out:
# The number of experiments is 1000, matrix size is 30
# The mean error value for random assignment is 434.001
# The mean error value for optimized assignement is 23.001

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
sb.distplot(random, label="random assignment")
plt.legend(loc='best')
plt.savefig('./random.png')

# %%
sb.distplot(optimized, label="optimized assignment")
plt.legend(loc='best')
plt.savefig('optimized.png')
